# %%
introduction to f string

# %%
firstname='amol'
lastname='jambhulkar'

fullname=f"{firstname} {lastname}"

print(fullname)
# Out:
# amol jambhulkar

# %%
print(fullname.title())
# Out:
# Amol Jambhulkar

# %%
message=f"keep it up good work amol, {fullname.title()}"
print(message)
# Out:
# keep it up good work amol, Amol Jambhulkar

# %% [markdown]
# concept of whitespaces

# %%
print('Fav_prog:pythonjavac++linux')
# Out:
# Fav_prog:pythonjavac++linux

# %%
print('Fav_prog:pythonjavac++linux')
# Out:
# Fav_prog:pythonjavac++linux

# %%
print('Fav_prog:python\n\tjava\n\tc++\n\tlinux')
# Out:
# Fav_prog:python
# 	java
# 	c++
# 	linux

# %%
eliinating whitespaces

# %%
name='  python'
print(name)
# Out:
#   python

# %%
name2= 'python    '
print(name2)
# Out:
# python

# %%
name3='python'

# %%
print("Amol")
# Out:
# Amol

# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %%
rules for declaring variables 

first name='amol'
# Out:
#   Cell In[3], line 1
#     rules for declaring variables
#           ^
# SyntaxError: invalid syntax

# %%
firstname='amol'

# %%
print(firstname)
# Out:
# amol

# %%
a variable number should not start with number
# Out:
#   Cell In[6], line 1
#     a variable number should not start with number
#       ^
# SyntaxError: invalid syntax

# %%
1name='amol'
# Out:
#   Cell In[7], line 1
#     1name='amol'
#     ^
# SyntaxError: invalid decimal literal

# %%
nam1='amol'

# %%
print(nam1)
# Out:
# amol

# %%
a variable name should not contain special character

test@='amol'
print(test@)
# Out:
#   Cell In[10], line 1
#     a variable name should not contain special character
#       ^
# SyntaxError: invalid syntax

# %%
name='amol'
print(name)
# Out:
# amol

# %%
name="amit"
print(name)
# Out:
# amit
